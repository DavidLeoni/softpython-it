# %%
import jupman
jupman.init()
# Out:
# <style>
#
#     #jupman-nav {
#         position: fixed;
#         top: 10px;
#         left: 5px;
#         background: white;
#         width: 200px;
#         padding: 10px;
#         z-index: 10;
#     }
#
#     /* style="background: rgba(255, 255, 255, 0);" class="unstyled" */
#
#     #jupman-toc {
#         position: fixed;
#         top: 100px;
#         left: -55px;
#         background: rgba(255, 255, 255, 0);
#
#         height: 80%;
#         width: 200px;
#         padding: 20px;
#         z-index: 10;
#         overflow-y: scroll;
#             /* font-size: 50%; */
#     }
#
#
#
#     code {
#         background-color:rgb(245, 249, 249) !important;
#     }
#
#
#     .jupman-nav-item {
#         font-weight:bold;
#         font-size:120%
#     }
#
#     .jupman-chapter-link {
#         font-size:150%;
#         margin-right:15px;
#     }
#
#     .jupman-chapter-link a {
#         text-decoration: none;
#     }
#
#     .jupman-title {
#         font-size:250%;
# ...

# %% [markdown]
# # Progetto d'esame
#
# **Per informazioni generali sulla modalità di esame, vedere descrizione corso alla sezione** [Crediti e valutazioni](about.ipynb#Crediti-e-valutazioni)
#
# **Tempi di consegna:**
#
# - Edizione Autunno 2017: il progetto va consegnato & approvato entro Domenica 18 Febbraio ore 24.00
# - Edizione Feb/Marzo 2018: il progetto va consegnato & approvato entro Martedì 31 Luglio ore 24.00
#
# **Idee per possibili progetti**: [Vedere qui](project-ideas.ipynb)
#
# Ultimo aggiornamento pagina: Giovedì 1 Marzo 2018
#
# Ai fini i ottenere i crediti formativi per l'attività, dovrete consegnare un piccolo progetto che dimostri che abbiate svolto le seguenti attività:
#
# 1. cercare dati da due / tre sorgenti, con attenzione alle licenze
# 2. pulirli (data cleaning)
# 3. fare qualche analisi (usando es. Pandas)
# 4. fare report in [Jupyter notebook](https://jupyter.org) scrivendo il [testo in Markdown](jm-templates/exam/project/NAME-SURNAME-ID/markdown.ipynb), con qualche grafico
# 5. possibilmente, aggiungere qualche aspetto interattivo, con widget o mappe in iframe
#
# * per avere i crediti riconosciuti, dovete portarmi un progetto decente (= che non sembri fatto la sera prima) !
# * Se il progetto è incorretto / mancano parti, potrei chiedervi di aggiustarlo e riportarlo
# * Se non venite mai ai laboratori, il "piccolo progetto" potrebbe perdere l'aggettivo "piccolo"

# %% [markdown]
# ## Requisiti tecnici
#
# <br/>
#
# <div class="alert alert-warning">
#
# **NOTA: non spaventatevi se i requisiti sembrano troppo formali: li ho scritti per limitare i problemi tecnici, se poi insorgono comunque pazienza!** L'idea è anche farvi capire cosa succede quando si riesegue codice su computer diversi dal proprio.
# </div>
#
#
# Tutto il codice nel notebook del progetto deve poter essere rieseguibile senza errori sul computer del docente. A tal fine:
#
# * Il progetto deve essere fatto in Python **3**
# * la versione esatta di tutte le librerie utilizzate deve essere scritta nel file `requirements.txt`.

# %% [markdown]
# ### File `requirements.txt`
#
# Tipicamente ogni progetto necessita di alcune librerie per funzionare. Invece di installarle una ad una con `pip`, si può comodamente elencarle in un file chiamato `requirements.txt`, e poi dire a `pip` di installarle tutte in un colpo solo.
#
# Per capire come compilare il file , guardate il `requirements.txt` di esempio fornito nello zip, in cui sono indicate tutte le librerie usate per i vari tutorial finora, assieme alla versione utilizzata. Se avete bisogno di usare altre librerie e / o cambiare le versioni, editate pure il file a piacere.
#
# #### Versioni dei pacchetti
#
# Per capire che versione avete installata di un dato pacchetto (i.e. `pandas`), eseguite questo comando:
#
# ```bash
# python3 -m pip show pandas
# ```
#
# Se avete installato il pacchetto, dovreste ottenere un output simile a questo:
#
# ```
# Name: pandas
# Version: 0.17.1
# Summary: Powerful data structures for data analysis, time series,and statistics
# Home-page: http://pandas.pydata.org
# Author: The PyData Development Team
# Author-email: pydata@googlegroups.com
# License: BSD
# Location: /usr/lib/python3/dist-packages
# Requires:
# ```
#
# Quindi in fase di valutazione del progetto, il docente:
#
# - creerà sul suo computer un ambiente virtuale nella cartella del progetto e lo attiverà
# - installerà tutte le librerie specificate in `requirements.txt` con il comando :
#     ```
#      python3 -m pip install -r requirements.txt
#     ```
# - aprirà il file `project.ipynb` in Jupyter e tenterà di rieseguire il codice con il comando `Kernel->Restart & run All`.
#
# Se tutto è predisposto correttamente, in teoria tutte le celle nel notebook si dovrebbero eseguire senza problemi di sorta.

# %% [markdown]
# ### Testo Markdown
#
# Il report deve essere scritto in Jupyter stesso, usando la sintassi Markdown descritta nel notebook [markdown.ipynb](jm-templates/exam/project/NAME-SURNAME-ID/markdown.ipynb) che trovate nello zip del progetto.
# Quindi _non_ mandatemi documenti in altri formati come `.pdf`, `.odt`, latex,  o peggio ancora i `.docx` di Word.
# L'unica eccezione sono i fogli di calcolo, vedere [sezione tabelle in Markdown](jm-templates/exam/project/NAME-SURNAME-ID/markdown.ipynb#Tabelle)

# %% [markdown]
# ## Che fare
#
# Prima di tutto, mandare per email a david.leoni@unitn.it una descrizione breve del progetto, così concorderemo cosa fare. Io creerò un Google doc per tenere traccia dei progressi e/o problemi riscontrati. Una volta delineato il progetto, proseguite:
#
# * Scaricate lo [zip con il template](_static/project-template.zip)
# * [Template online](jm-templates/exam/project/NAME-SURNAME-ID/project.ipynb)
# * [Naviga files online](https://github.com/DavidLeoni/softpython/tree/master/jm-templates/exam/project/NAME-SURNAME-ID/)
#
# Una volta szippato il template, troverete una cartella chiamata `NAME-SURNAME-ID`, dentro contiene questi file:
#
# ```
# - NAME-SURNAME-ID
#     - project.ipynb
#     - markdown.ipynb
#     - requirements.txt
#     - img
#         - example.png
# ```
#
# 1. Rinominate la cartella con i tuoi dati
# 2. lanciate Jupyter dalla cartella appena rinominata
# 3. editate il file `project.ipynb`
# 4. una volta finito, mandatete  il progetto per email a david.leoni@unitn.it
#
# Se avete difficoltà potete anche mandare versioni intermedie, e proverò ad aiutarvi il prima possibile.

# %% [markdown]
# ## Fare attenzione a
#
# - non mischiare unità di misura diverse
# - celle vuote
# - problemi di encoding
# - sostituzioni regex sbagliate
# - usare scale giuste nel grafico (magari serve la logaritmica ?)

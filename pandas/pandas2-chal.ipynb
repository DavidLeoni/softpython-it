# %% [markdown]
# # Challenge Pandas
#
# ## [Scarica zip esercizi](../_static/generated/pandas.zip)
#
# [Naviga file online](https://github.com/DavidLeoni/softpython-it/pandas)

# %% [markdown]
# Proponiamo ora degli esercizi senza soluzione, accetti la sfida?

# %% [markdown]
# ## Sfida - Euregio
#
# ✪✪ L’EuregioFamilyPass è un progetto congiunto del GECT Euregio Tirolo-Alto Adige-Trentino, del Dipartimento Societá e Lavoro del Land Tirolo e delle Agenzie per la famiglia delle Province autonome di Bolzano e di Trento.
# che mira a favorire la mobilità e gli scambi culturali tra le famiglie delle tre province dell’ Euregio
#
# L’EuregioFamilyPass permette di accedere a livello transfrontaliero ad una offerta di vantaggi e servizi riservate alle famiglie, attraverso partner convenzionati tra cui sia enti pubblici che esercenti privati.
#
# Sorgente dati: [dati.trentino.it](https://dati.trentino.it/dataset/elenco-aderenti-euregio-family-pass/resource/cbae521f-f87e-4d82-b322-40b2691b950c)
#
# Vediamo come filtrare questi servizi: apri il file [aderenti-euregiofamilycard.csv](aderenti-euregiofamilycard.csv) con pandas ed **encoding UTF-8**,  assegnalo alla variabile `edf` e mostra i suoi campi

# %%
# scrivi qui
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_Servizio     35 non-null     int64
#  1   ServiceNameIT   35 non-null     object
#  2   ServiceNameDE   35 non-null     object
#  3   Category        35 non-null     object
#  4   URL             35 non-null     object
#  5   MobileContact   35 non-null     object
#  6   Email           35 non-null     object
#  7   AddressIT       35 non-null     object
#  8   AddressDE       35 non-null     object
#  9   MunicipalityIT  35 non-null     object
#  10  MunicipalityDE  35 non-null     object
#  11  DistrictIT      35 non-null     object
#  12  DistrictDE      35 non-null     object
#  13  Valid_from      35 non-null     object
#  14  Valid_until     35 non-null     object
#  15  InfoBonus       35 non-null     bool
#  16  Latitude        35 non-null     float64
# ...

# %% [markdown]
# ### Categoria b1
#
# Trova tutte i servizi aventi la categoria b1

# %%
# scrivi qui
# Out:
#     id_Servizio                                      ServiceNameIT  \
# 0             1          Museo Casa Alcide DeGasperi, Pieve Tesino
# 1             2      Museo Storico Italiano della Guerra, Rovereto
# 2             3                             La Tana dell'Ermellino
# 3             4                                         Andel Haus
# 4             5                                          Dal Barba
# 5             6                            Castel Stenico, Stenico
# 6             7                           Castel Beseno, Besenello
# 7             8                 Castello del Buonconsiglio, Trento
# 8             9                            Castello Caldes, Caldes
# 9            10                           Castel Thun, Vigo di Ton
# 10           11      Giardino Botanico Alpino, Viote Monte Bondone
# 11           12      Museo dell’Aeronautica Gianni Caproni, Trento
# 12           13                   MUSE Museo delle Scienze, Trento
# ...

# %% [markdown]
# ### Categoria b3 o b9
#
# Trova tutte i servizi aventi la categoria b3 oppure la b9

# %%
# scrivi qui
# Out:
#     id_Servizio               ServiceNameIT               ServiceNameDE  \
# 2             3      La Tana dell'Ermellino      La Tana dell'Ermellino
# 3             4                  Andel Haus                  Andel Haus
# 4             5                   Dal Barba                   Dal Barba
# 31           32     Swimfamily Castel Ivano     Swimfamily Castel Ivano
# 32           33  Swimfamily Borgo Valsugana  Swimfamily Borgo Valsugana
# 33           34     Swimfamily Levico Terme     Swimfamily Levico Terme
# 34           35          Sanifonds Trentino          Sanifonds Trentino
#
#        Category                                                URL  \
# 2   b3, b4, b11        https://www.facebook.com/tanadellermellino/
# 3   b3, b4, b11  https://www.facebook.com/ristorantepizzeriaand...
# 4   b3, b4, b11                    https://www.locandadalbarba.it/
# 31   b3, b4, b5       https://www.waterway.it/centri/castel-ivano/
# ...

# %% [markdown]
# ### facebook
#
# Trovare tutti i nomi dei servizi che hanno una pagina facebook

# %%
# scrivi qui
# Out:
#             ServiceNameIT                                                URL
# 2  La Tana dell'Ermellino        https://www.facebook.com/tanadellermellino/
# 3              Andel Haus  https://www.facebook.com/ristorantepizzeriaand...

# %% [markdown]
# ### Mail di Trento
#
# Estrarre le mail di tutti i servizi di Trento, senza mostrare duplicati
#
# * **SUGGERIMENTO**: usare [pd.unique](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.unique.html)

# %%
# scrivi qui
# Out:
# array(['info@buonconsiglio.it', 'info@museostorico.it',
#        'museinfo@muse.it', 'info@mart.tn.it',
#        'uff.beniarcheologici@provincia.tn.it',
#        'segnalazioni@ttesercizio.it', 'info@sanifonds.tn.it'],
#       dtype=object)

# %% [markdown]
# ### Colonna b4
#
# Aggiungere una nuova colonna b4 che sia `True` se il servizio appartiene alla categoria b4 e `False` altrimenti

# %%
# scrivi qui

# %%
edf
# Out:
#     id_Servizio                                      ServiceNameIT  \
# 0             1          Museo Casa Alcide DeGasperi, Pieve Tesino
# 1             2      Museo Storico Italiano della Guerra, Rovereto
# 2             3                             La Tana dell'Ermellino
# 3             4                                         Andel Haus
# 4             5                                          Dal Barba
# 5             6                            Castel Stenico, Stenico
# 6             7                           Castel Beseno, Besenello
# 7             8                 Castello del Buonconsiglio, Trento
# 8             9                            Castello Caldes, Caldes
# 9            10                           Castel Thun, Vigo di Ton
# 10           11      Giardino Botanico Alpino, Viote Monte Bondone
# 11           12      Museo dell’Aeronautica Gianni Caproni, Trento
# 12           13                   MUSE Museo delle Scienze, Trento
# ...

# %% [markdown]
# ## Sfida - Pulizia strade
#
# ✪✪✪ Vediamo gli orari della pulizia delle strade del Comune di Trento
#
# Sorgnete dati: [dati.trentino.it](https://dati.trentino.it/dataset/pulizia-strade-e-relativi-divieti-di-sosta-primavera-2021-open-data)
#
# Apri il file [pulizia-strade.csv](pulizia-strade.csv) con pandas ed **encoding UTF-8**, assegnalo alla variabile `psdf` e mostra i suoi campi

# %%
# scrivi qui

# %% [markdown]
# ### E' ora di finirla
#
# Stampa le strade la cui pulizia finisce alle 2.30

# %%
# scrivi qui
# Out:
#      strada                     desvia  percorso      lato  \
# 52     3050             LARGO N. SAURO        11  entrambi
# 53     3650              VIA A. SCHMID        11  entrambi
# 54      480        CORSO M. BUONARROTI        11     ovest
# 55     1570             VIA E. MACCANI        11       est
# 56     1170    VIA FELICE E G. FONTANA        11  entrambi
# 57      100         CORSO DEGLI ALPINI        11       est
# 58     3290        VIA TORRE D'AUGUSTO        11  entrambi
# 59     1660         VIA DELLA MALVASIA        11  entrambi
# 60     2320          PIAZZA S. PELLICO        11  entrambi
# 61       20              VIA A. ABONDI        11  entrambi
# 62     2820            VIA SAN MARTINO        11  entrambi
# 63     3590       VIA DI CAMPOTRENTINO        11  entrambi
# 64     3660              VIA L. SENESI        11  entrambi
# 97     1810             VIA C. MARTINI        18  entrambi
# 98     3500             VIA A. VIVALDI        18  entrambi
# ...

# %% [markdown]
# ### Strade a colpo d'occhio
#
# Ogni strada compare al massimo una volta oppure ci sono strade che compaiono più volte nel dataset?
#
# Usiamo l'istogramma per vederlo subito a colpo d'occhio!
#
# Plotta l'istogramma delle occorrenze delle strade nel dataset
#
# **SUGGERIMENTO**: usa [pandas.hist](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html)

# %%
# scrivi qui
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Due strade
#
# Stampa le strade che ricorrono due volte nel dataset

# %%
# scrivi qui
# Out:
#      strada                    desvia  percorso      lato  \
# 0      3030   PIAZZA RAFFAELLO SANZIO         8  entrambi
# 10     2990  PIAZZA S. MARIA MAGGIORE        12  entrambi
# 19     2670            VIA A. ROSMINI        12       est
# 21     3440              VIA G. VERDI        12  entrambi
# 24     1570            VIA E. MACCANI        10  entrambi
# ..      ...                       ...       ...       ...
# 286    1700              VIA G. MANCI         6  entrambi
# 302    2990  PIAZZA S. MARIA MAGGIORE         5  entrambi
# 308    1130           PIAZZA DI FIERA         7  entrambi
# 316    1230          VIA G. GARIBALDI         7  entrambi
# 318    3440              VIA G. VERDI         7  entrambi
#
#                                                 tratto  note data pulizia  \
# 0    da incrocio  Via A. Manzoni ad inizio Via G.D....   NaN     12/04/21
# 10    tratto da Via della Prepositura a Via A. Rosmini   NaN     13/04/21
# ...

# %% [markdown]
# ### Due strade stesso percorso
#
# Stampa le strade che ricorrono due volte nello stesso percorso

# %%
# scrivi qui
# Out:
# VIA DEL BRENNERO
# CORSO DEGLI ALPINI
# VIA E. MACCANI
# VIA VITTORIO VENETO
# VIA G. MATTEOTTI
